# %%
from Fundamentals import Tickertape
import pandas as pd

# %%
ttp = Tickertape()

# %%
# Searching in tickertape
res, raw_data = ttp.get_ticker('Adani wilmar')
print(res)
raw_data[0]
# Out:
# AWL
# {'marketCap': 42038.104478725,
#  'ticker': 'AWL',
#  'brands': [],
#  'searchTags_keyword': ['adani wilmar ltd', 'awl'],
#  'marketCapRank': 210,
#  'searchTags': ['adani wilmar ltd', 'awl'],
#  'exchanges': 'NSE',
#  'weight': 1,
#  'ticker_keyword': 'AWL',
#  'suspended': False,
#  'sid': 'AWL',
#  'name_suggest': 'Adani Wilmar Ltd',
#  'brands_keyword': [],
#  'name_keyword': 'Adani Wilmar Ltd',
#  'ticker_suggest': 'AWL',
#  'name': 'Adani Wilmar Ltd',
#  'id': 'AWL',
#  'sector': 'Consumer Staples',
#  'ticker_key': 'AWL',
#  'slug': '/stocks/adani-wilmar-AWL',
#  'quote': {'sid': 'AWL',
#   'price': 291.1,
#   'close': 323.45,
#   'change': -32.35,
#   'high': 301.6,
#   'low': 291.1,
#   'volume': 17146053,
#   'date': '2025-01-10T10:28:12.000Z'},
#  'score': 2187.5227,
#  'index': 'stock',
#  'type': 'stock',
#  'match': 'EXACT'}

# %%
# Allowed search_places = ['stock', 'index', 'etf', 'mutualfund', 'space', 'profile', 'smallcase', 'all']
_, raw_data = ttp.get_ticker('Nifty 500', search_place='index')
raw_data[1] # here ticker is the unique id of NSE and sid is the id of Tickertape
# Out:
# {'marketCap': '39726584.15',
#  'ticker': 'NIFTY 500',
#  'weight': 1,
#  'ticker_keyword': 'NIFTY 500',
#  'type': 'index',
#  'suspended': False,
#  'sid': '.NIFTY500',
#  'name_suggest': 'Nifty 500 Index',
#  'name_keyword': 'Nifty 500 Index',
#  'ticker_suggest': 'NIFTY 500',
#  'name': 'Nifty 500 Index',
#  'id': '.NIFTY500',
#  'sector': 'Index',
#  'ticker_key': 'NIFTY 500',
#  'slug': '/indices/nifty-500-index-.NIFTY500',
#  'quote': {'sid': '.NIFTY500',
#   'price': 21799,
#   'close': 22046.55,
#   'change': -247.55,
#   'high': 22075.4,
#   'low': 21738.45,
#   'volume': 0,
#   'date': '2025-01-10T10:28:59.519Z'},
#  'score': 1178.5251,
#  'index': 'index',
#  'match': 'EXACT'}

# %%
# Get all tickers (sid in Tickertape) of NIFTY 50
ttp.get_all_nifty_50_ticker()
# Out:
# ['APSE',
#  'ADEL',
#  'APLH',
#  'AXBK',
#  'ASPN',
#  'BJFS',
#  'BAJA',
#  'BJFN',
#  'BAJE',
#  'BRIT',
#  'BRTI',
#  'BPCL',
#  'CIPL',
#  'COAL',
#  'REDY',
#  'EICH',
#  'GRAS',
#  'HALC',
#  'HDBK',
#  'HDFL',
#  'HCLT',
#  'HLL',
#  'HROM',
#  'ICBK',
#  'ITC',
#  'INFY',
#  'INBK',
#  'JSTL',
#  'KTKM',
#  'LART',
#  'MAHM',
#  'MRTI',
#  'NEST',
#  'ONGC',
#  'NTPC',
#  'PGRD',
#  'RELI',
#  'SBI',
#  'SBIL',
#  'SRTR',
#  'SUN',
#  'TISC',
#  'TACN',
#  'TAMO',
#  'TCS',
#  'TEML',
#  'TITN',
#  'TREN',
#  'ULTC',
#  'WIPR']

# %%
# Get all tickers of an Index
ttp.get_all_constituents_of_index('.NIFTY500')
# Out:
#                           _id    sid     ticker  \
# 0    5f6c78c9896509a8eb2f90e6   ADIA      ABFRL
# 1    5f6c78c9896509a8eb2f9120   AFFL      AFFLE
# 2    5f6c78c9896509a8eb2f90fe   ACEL        ACE
# 3    5f6c78c9896509a8eb2f90d4   ARTI   AARTIIND
# 4    5f6c78c9896509a8eb2f90f6    ACC        ACC
# ..                        ...    ...        ...
# 495  664410373a672e86eb74a743    TBO     TBOTEK
# 496  664410373a672e86eb74a744   AADH  AADHARHFC
# 497  664ea9de8f4d62459b86f1c6  GODIG    GODIGIT
# 498  668de42285c940495c1022ff    EMC     EMCURE
# 499  66b17ca3e35bbc2d291ecb01    AKU      AKUMS
#
#                                     name                  sector  lastPrice  \
# 0    Aditya Birla Fashion and Retail Ltd  Consumer Discretionary     274.10
# 1                      Affle (India) Ltd  Communication Services    1601.55
# 2      Action Construction Equipment Ltd             Industrials    1342.20
# 3                   Aarti Industries Ltd               Materials     421.75
# 4                                ACC Ltd               Materials    1931.05
# ..                                   ...                     ...        ...
# 495                          Tbo Tek Ltd  Consumer Discretionary    1741.30
# 496           Aadhar Housing Finance Ltd              Financials     422.95
# 497       Go Digit General Insurance Ltd              Financials     285.15
# 498           Emcure Pharmaceuticals Ltd             Health Care    1357.90
# 499  Akums Drugs and Pharmaceuticals Ltd             Health Care     618.25
#
#          pr1d                                          slug  freeFloat   type
# 0   -0.885916  /stocks/aditya-birla-fashion-and-retail-ADIA  40.023886  stock
# 1   -2.626539                      /stocks/affle-india-AFFL   5.601319  stock
# 2   -4.042895    /stocks/action-construction-equipment-ACEL   3.948084  stock
# 3    2.019836                 /stocks/aarti-industries-ARTI  20.680983  stock
# 4   -2.165873                               /stocks/acc-ACC   7.986083  stock
# ..        ...                                           ...        ...    ...
# 495 -0.091801                           /stocks/tbo-tek-TBO   1.702202  stock
# 496  0.118357           /stocks/aadhar-housing-finance-AADH  10.311849  stock
# 497 -4.070648      /stocks/go-digit-general-insurance-GODIG  16.661578  stock
# 498 -5.497947            /stocks/emcure-pharmaceuticals-EMC   2.534311  stock
# 499  0.137674   /stocks/akums-drugs-and-pharmaceuticals-AKU   2.307621  stock
#
# [500 rows x 10 columns]

# %% [markdown]
# # Annual Report/ Quarterly Results extracted data
# # some params meanings
# time_horizon -> result time period (annual / interim (quarterly) )
# time_period -> count of records required (any integer (less than 20))
# view_type -> **normal** - just show the numbers as is,  **growth** - what is the % of increase happened compared to last entry (either Annually or Quarterly)

# %%
ttp.get_income_data('ADAI') # time_horizon = interim (quarterly), time_periods = 10 (10 qtrs), view = Normal
# Out:
#   displayPeriod                   endDate     reporting  qIncTrev qIncRaw  \
# 0      JUN 2022  2022-06-30T00:00:00.000Z  consolidated   3784.42    None
# 1      SEP 2022  2022-09-30T00:00:00.000Z  consolidated   3449.56    None
# 2      DEC 2022  2022-12-31T00:00:00.000Z  consolidated   3781.94    None
# 3      MAR 2023  2023-03-31T00:00:00.000Z  consolidated   3860.12    None
# 4      JUN 2023  2023-06-30T00:00:00.000Z  consolidated   3772.25    None
# 5      SEP 2023  2023-09-30T00:00:00.000Z  consolidated   3766.46    None
# 6      DEC 2023  2023-12-31T00:00:00.000Z  consolidated   4824.42    None
# 7      MAR 2024  2024-03-31T00:00:00.000Z  consolidated   4910.78    None
# 8      JUN 2024  2024-06-30T00:00:00.000Z  consolidated   5489.97    None
# 9      SEP 2024  2024-09-30T00:00:00.000Z  consolidated   6359.80    None
#
#   qIncPfc qIncEpc qIncSga  qIncOpe  qIncEbi  qIncDep  qIncPbi  qIncIoi  \
# 0    None    None    None  2458.63  1325.79   383.98   941.81   739.98
# 1    None    None    None  2087.86  1361.70   397.84   963.86   713.91
# 2    None    None    None  2074.16  1707.78   410.37  1297.41   697.09
# 3    None    None    None  2154.46  1705.66   415.55  1290.11   630.49
# 4    None    None    None  2394.61  1377.64   418.88   958.76   615.67
# 5    None    None    None  2323.73  1442.73   432.05  1010.68   640.81
# 6    None    None    None  3092.09  1732.33   457.64  1274.69   760.04
# 7    None    None    None  3141.33  1769.45   467.51  1301.94   749.99
# 8    None    None    None  5233.89   256.08   497.85  -241.77   810.93
# 9    None    None    None  4468.56  1891.24   484.07  1407.17   812.94
#
#    qIncPbt  qIncToi  qIncNinc  qIncEps qIncDps qIncPyr
# 0   201.83    15.84    185.99     1.50    None    None
# 1   249.95    43.78    206.17     1.85    None    None
# 2   600.32   125.60    474.72     4.26    None    None
# 3   659.62   270.17    389.45     3.49    None    None
# 4   343.09   168.03    175.06     1.57    None    None
# 5   369.87    93.99    275.88     2.47    None    None
# 6   514.65   189.75    324.90     2.92    None    None
# 7   551.95   190.51    361.44     3.24    None    None
# 8 -1052.70  -228.78   -823.92    -7.39    None    None
# 9   594.23   -80.73    674.96     6.09    None    None

# %%
ttp.get_income_data('ACC', time_horizon='annual', view_type='growth', num_time_periods=12)
# Out:
#         incTrev  incCrev  incGpro  incOpc       incRaw       incPfc  \
# 0  22568.220000      NaN      NaN     NaN  5646.910000  5742.720000
# 1     -8.303579      NaN      NaN     NaN     2.308342   -30.294355
# 2      0.348938      NaN      NaN     NaN          NaN          NaN
#
#         incEpc       incSga       incOpe      incEbi  ...      incIoi  \
# 0  1036.200000  6208.850000  1812.340000  2121.20000  ...   77.280000
# 1   -28.855433   -18.697182   -26.513237    79.00198  ...  100.025880
# 2          NaN          NaN     2.205328    -7.91232  ...    8.041144
#
#         incPbt      incToi     incNinc      incEps     incDps     incPyr  \
# 0  1202.600000  317.530000  885.070000   46.984707   9.250000   0.196873
# 1   129.444537   33.193714  163.975731  163.975731 -18.918919 -69.284646
# 2   -13.657449  -19.450027  -12.608876  -12.608876   0.000000  14.428097
#
#      displayPeriod     reporting endDate
# 0          FY 2023  consolidated     NaN
# 1  FY '23 - FY '24           NaN     NaN
# 2              TTM
#
# [3 rows x 22 columns]

# %%
ttp.get_balance_sheet_data('ARTI', num_time_periods=16, growth=True)
# Out:
#        balCsti     balTrec     balTinv      balOca       balTca balNetl  \
# 0    33.710000  438.980000  551.730000  173.240000  1197.660000    None
# 1   -14.001780   19.230944  -10.247766    7.602170     3.033415    None
# 2    -1.690238    0.242644   15.392072    3.326002     6.742356    None
# 3    12.631579   24.792727   30.781750   30.206116    27.919283    None
# 4  2405.295950   18.524628    3.277131  -10.251605    52.949660    None
# 5   -69.250187   -2.912221    8.278159  -25.155500   -22.204718    None
# 6    66.735412    5.347473   11.966303   34.079307    18.092445    None
# 7   -57.906480   37.517796   -0.166724  121.202462    13.990117    None
# 8    15.654529  -13.836668   10.376611  -42.557493    -8.876439    None
# 9   -35.370896  -12.136227   12.472722   23.055749     0.391580    None
#
#        balNppe     balGint      balLti     balOtha  ...       balTeq  \
# 0  1159.900000    0.000000  139.200000  441.060000  ...  1022.270000
# 1    34.369342         NaN  -70.359195  -70.013150  ...    16.347932
# 2    26.041513  404.761905   13.814833   27.294723  ...    19.920295
# 3    23.822808  -18.867925    0.553663   33.749109  ...    16.064418
# 4    20.864989  -23.255814  -29.775519   36.082245  ...    63.986831
# 5    32.153596  -30.303030   11.610374   32.000783  ...    13.212044
# 6    25.871961  -89.130435   71.629289  -20.870726  ...    14.373379
# 7     1.027525 -100.000000  -55.462846  -51.513731  ...    28.492749
# 8    20.574865         NaN  -39.307176  -39.100458  ...     8.946797
# 9    15.355781         NaN   33.488643    7.607661  ...     7.512600
#
#        balTlse    balTcso  balTpso       balNca        balCa      balNcl  \
# 0  2937.820000  42.394489     None  1740.160000  1197.660000  827.750000
# 1     0.975553  -5.950111     None    -0.440764     3.033415  -20.990637
# 2    17.952927  -1.440224     None    25.937812     6.742356   15.035168
# 3    25.504351  -0.999000     None    24.046456    27.919283   52.815919
# 4    33.393905   6.603502     None    21.219500    52.949660    5.338007
# 5     8.101141  -3.727968     None    31.906560   -22.204718   10.874035
# 6    20.673983   0.000000     None    21.869938    18.092445   28.572918
# 7     2.735132   4.029005     None    -2.317371    13.990117  -32.325070
# 8     9.301221 -12.727019     None    18.823687    -8.876439  -24.955064
# 9    12.057127   0.000000     None    16.743580     0.391580   99.436575
#
#        balDta    displayPeriod     reporting
# 0         NaN          FY 2015  consolidated
# 1         NaN  FY '15 - FY '16           NaN
# 2         NaN  FY '16 - FY '17           NaN
# 3         NaN  FY '17 - FY '18           NaN
# 4         NaN  FY '18 - FY '19           NaN
# 5         NaN  FY '19 - FY '20           NaN
# 6         NaN  FY '20 - FY '21           NaN
# 7         NaN  FY '21 - FY '22           NaN
# 8   90.266763  FY '22 - FY '23           NaN
# 9  171.978022  FY '23 - FY '24           NaN
#
# [10 rows x 35 columns]

# %%
ttp.get_balance_sheet_data('ALKY', num_time_periods=10) # View_type = Normal
# Out:
#   displayPeriod                   endDate   reporting  balCsti  balTrec  \
# 0       FY 2015  2015-03-31T00:00:00.000Z  standalone     7.86    98.93
# 1       FY 2016  2016-03-31T00:00:00.000Z  standalone     4.27    90.30
# 2       FY 2017  2017-03-31T00:00:00.000Z  standalone     2.96    97.34
# 3       FY 2018  2018-03-31T00:00:00.000Z  standalone     3.23   123.78
# 4       FY 2019  2019-03-31T00:00:00.000Z  standalone    20.17   152.63
# 5       FY 2020  2020-03-31T00:00:00.000Z  standalone    32.26   164.22
# 6       FY 2021  2021-03-31T00:00:00.000Z  standalone   156.28   227.99
# 7       FY 2022  2022-03-31T00:00:00.000Z  standalone    62.57   276.74
# 8       FY 2023  2023-03-31T00:00:00.000Z  standalone    18.23   258.42
# 9       FY 2024  2024-03-31T00:00:00.000Z  standalone    31.38   221.73
#
#    balTinv  balOca  balTca balNetl    balNppe  ...  balRtne  balOeq   balTeq  \
# 0    70.54   21.10  198.43    None   181.2422  ...   151.70    0.00   174.82
# 1    63.16   26.08  183.81    None   202.9415  ...   176.35    0.00   199.47
# 2   111.41   13.31  225.02    None   254.4792  ...   222.45    0.00   245.57
# 3    85.18   26.19  238.38    None   373.2459  ...   274.04    0.00   297.16
# 4   105.69   33.53  312.02    None   419.2659  ...   341.88    0.00   365.00
# 5    83.67   14.00  294.15    None   468.0687  ...   513.48    0.00   536.60
# 6   122.04   21.76  528.07    None   595.6700  ...   767.86    0.12   792.45
# 7   164.61   33.73  537.65    None   771.5900  ...   963.33    0.00   989.80
# 8   183.85   40.32  500.82    None  1071.1900  ...  1140.06    0.00  1168.93
# 9   172.38   18.28  443.77    None  1124.8000  ...  1236.62    0.00  1267.14
#
#    balTlse   balTcso balTpso   balNca   balCa  balNcl  balDta
# 0   402.03  5.101048    None   203.60  198.43   79.03    None
# 1   406.39  5.101048    None   222.58  183.81   75.97    None
# 2   512.21  5.099098    None   287.19  225.02  106.07    None
# 3   637.05  5.099098    None   398.67  238.38  160.35    None
# 4   748.51  5.099098    None   436.49  312.02  135.75    None
# 5   783.39  5.099098    None   489.24  294.15   92.98    None
# 6  1145.49  5.103178    None   617.42  528.07   71.10    None
# 7  1371.40  5.107245    None   833.75  537.65   53.60    None
# 8  1592.09  5.110063    None  1091.27  500.82   68.80    None
# 9  1584.04  5.112139    None  1140.27  443.77   88.56    None
#
# [10 rows x 36 columns]

# %%
ttp.get_cash_flow_data('TCS', num_time_periods=10, growth=False) # these 2 are default values ideally no need to pass {num_time_periods=10, growth=False}
# Out:
#   displayPeriod                   endDate     reporting   cafCiwc   cafCfoa  \
# 0       FY 2015  2015-03-31T00:00:00.000Z  consolidated  -6734.54  19368.78
# 1       FY 2016  2016-03-31T00:00:00.000Z  consolidated -12522.00  19109.00
# 2       FY 2017  2017-03-31T00:00:00.000Z  consolidated  -8577.00  25223.00
# 3       FY 2018  2018-03-31T00:00:00.000Z  consolidated  -7818.00  25067.00
# 4       FY 2019  2019-03-31T00:00:00.000Z  consolidated -12127.00  28593.00
# 5       FY 2020  2020-03-31T00:00:00.000Z  consolidated -10513.00  32369.00
# 6       FY 2021  2021-03-31T00:00:00.000Z  consolidated  -8229.00  38802.00
# 7       FY 2022  2022-03-31T00:00:00.000Z  consolidated -14255.00  39949.00
# 8       FY 2023  2023-03-31T00:00:00.000Z  consolidated -17183.00  41965.00
# 9       FY 2024  2024-03-31T00:00:00.000Z  consolidated -19371.00  44338.00
#
#    cafCexp   cafCfia   cafTcdp   cafCffa cafFee  cafNcic    cafFcf
# 0   2949.2  -1807.14  17105.57 -17167.61   None   394.03  16419.58
# 1   1987.0  -5010.00   9515.00  -9666.00   None  4433.00  17122.00
# 2   1989.0 -16895.00  10973.00 -11026.00   None -2698.00  23234.00
# 3   1862.0   3104.00  10760.00 -26885.00   None  1286.00  23205.00
# 4   2231.0   1645.00  11472.00 -27897.00   None  2341.00  26362.00
# 5   3249.0   8968.00  37702.00 -39915.00   None  1422.00  29120.00
# 6   3176.0  -7956.00  10907.00 -32634.00   None -1788.00  35626.00
# 7   2995.0   -738.00  13375.00 -33581.00   None  5630.00  36954.00
# 8   3100.0    548.00  41410.00 -47878.00   None -5365.00  38865.00
# 9   2674.0   6091.00  25218.00 -48536.00   None  1893.00  41664.00

# %% [markdown]
# # Peers Comparison
# comparison type is either `valuation` (default) or  `Technical`

# %%
ttp.peers_comparison('TCS') # this comparison is based on valuation
# Out:
#                             name   ticker   sid                    sector  \
# 0  Tata Consultancy Services Ltd      TCS   TCS  IT Services & Consulting
# 1                    Infosys Ltd     INFY  INFY  IT Services & Consulting
# 2           HCL Technologies Ltd  HCLTECH  HCLT  IT Services & Consulting
# 3                      Wipro Ltd    WIPRO  WIPR  IT Services & Consulting
# 4                LTIMindtree Ltd     LTIM  LRTI  IT Services & Consulting
#
#                                       slug  \
# 0    /stocks/tata-consultancy-services-TCS
# 1                     /stocks/infosys-INFY
# 2            /stocks/hcl-technologies-HCLT
# 3                       /stocks/wipro-WIPR
# 4  /stocks/larsen-and-toubro-infotech-LRTI
#
#                                          description  ratios_ttmPe  \
# 0  Tata Consultancy Services Limited (TCS) is eng...     31.650011
# 1                                                NaN     30.231807
# 2                                                NaN     32.083471
# 3                                                NaN     26.749278
# 4                                                NaN     38.985151
#
#    ratios_pbr  ratios_divDps  ratios_apef
# 0   16.900640       1.711345    33.618313
# 1    9.209900       2.337471    31.056950
# 2    7.908199       2.613640    34.384196
# 3    4.206114       0.166375    28.433883
# 4    9.059107       1.060547    39.593483

# %%
ttp.peers_comparison('TAMO', comparison_type='technical')
# Out:
#                         name      ticker   sid         sector  \
# 0            Tata Motors Ltd  TATAMOTORS  TAMO  Four Wheelers
# 1  Mahindra and Mahindra Ltd         M&M  MAHM  Four Wheelers
# 2    Maruti Suzuki India Ltd      MARUTI  MRTI  Four Wheelers
# 3    Hyundai Motor India Ltd     HYUNDAI   HYU  Four Wheelers
# 4           Force Motors Ltd    FORCEMOT  FORC  Four Wheelers
#
#                                  slug  \
# 0            /stocks/tata-motors-TAMO
# 1  /stocks/mahindra-and-mahindra-MAHM
# 2    /stocks/maruti-suzuki-india-MRTI
# 3     /stocks/hyundai-motor-india-HYU
# 4           /stocks/force-motors-FORC
#
#                                          description  ratios_12mVol  \
# 0  Tata Motors Limited is an automobile company e...      29.343969
# 1                                                NaN      32.103124
# 2                                                NaN      24.108085
# 3                                                NaN      26.209531
# 4                                                NaN      55.325347
#
#    ratios_14dRsi
# 0      66.124920
# 1      65.459218
# 2      66.971197
# 3      55.049552
# 4      48.364680

# %% [markdown]
# # TickerTape SCORE CARD

# %%
ttp.get_score_card('INFY')
# Out:
#             name   tag        type  \
# 0    Performance   Low       score
# 1      Valuation  High       score
# 2         Growth   Low       score
# 3  Profitability  High       score
# 4    Entry point  Good  entryPoint
# 5      Red flags   Low     redFlag
#
#                                          description colour  rank peers  \
# 0     Hasn't fared well - amongst the low performers    red  None  None
# 1       Seems to be overvalued vs the market average    red  None  None
# 2     Lagging behind the market in financials growth    red  None  None
# 3   Showing good signs of profitability & efficiency  green  None  None
# 4  The stock is underpriced and is not in the ove...  green  None  None
# 5                                  No red flag found  green  None  None
#
#    locked callout comment  stack  \
# 0    True    None    None      1
# 1    True    None    None      2
# 2    True    None    None      3
# 3    True    None    None      4
# 4   False    None    None      5
# 5   False    None    None      6
#
#                                             elements score_percentage  \
# 0                                                 []            False
# 1                                                 []            False
# 2                                                 []            False
# 3                                                 []            False
# 4  [{'title': 'Fundamentals', 'type': 'flag', 'de...              NaN
# 5  [{'title': 'ASM', 'type': 'flag', 'description...              NaN
#
#    score_max  score_value      score_key  score
# 0       10.0          NaN    Performance    NaN
# 1       10.0          NaN      Valuation    NaN
# 2       10.0          NaN         Growth    NaN
# 3       10.0          NaN  Profitability    NaN
# 4        NaN          NaN            NaN    NaN
# 5        NaN          NaN            NaN    NaN

# %% [markdown]
# # Share Holding Pattern Q-O-Q

# %%
_, raw_data = ttp.get_ticker('Tata consult') # TCS
slug_url = raw_data[0].get('slug')
print(slug_url)
ttp.get_share_holding_pattern(slug_url)
# Out:
# /stocks/tata-consultancy-services-TCS
#                        date  data_pmPctT  data_pmPctP  data_plPctT  \
# 0  2023-06-30T00:00:00.000Z    72.297047     0.477552     0.345256
# 1  2023-09-30T00:00:00.000Z    72.297047     0.477552     0.345256
# 2  2023-12-31T00:00:00.000Z    72.412804     0.482187     0.349165
# 3  2024-03-31T00:00:00.000Z    71.766054     0.275750     0.197895
# 4  2024-06-30T00:00:00.000Z    71.766054     0.275750     0.197895
# 5  2024-09-30T00:00:00.000Z    71.766054     0.275750     0.197895
#
#    data_uPlPctT  data_mfPctT  data_isPctT  data_diPctT  data_othDiPctT  \
# 0     71.951791     3.482790     5.737781     9.808078        6.325288
# 1     71.951791     3.490914     5.898061    10.064172        6.573258
# 2     72.063639     3.508293     5.917744    10.088976        6.580683
# 3     71.568159     4.051627     5.977892    10.668815        6.617188
# 4     71.568159     4.249089     6.127442    11.057136        6.808047
# 5     71.568159     4.248089     5.960481    10.911053        6.662963
#
#    data_othExInsDiPctT  data_fiPctT  data_rhPctT  data_othPctT  data_rOthPctT
# 0             0.587508    12.514083     4.494516      0.886277       5.380793
# 1             0.675197    12.471288     4.309378      0.858114       5.167493
# 2             0.662940    12.469608     4.188144      0.840468       5.028612
# 3             0.639296    12.699170     4.047523      0.818438       4.865961
# 4             0.680605    12.356210     4.029737      0.790864       4.820600
# 5             0.702482    12.657080     3.888777      0.777037       4.665814

# %% [markdown]
# # Mutual Funds Holdings of an Equity

# %%
_, raw_data = ttp.get_ticker('tata consumer')
slug_url = raw_data[0].get('slug')
print(slug_url)
ttp.get_mutual_fund_holdings(slug_url)
# Out:
# /stocks/tata-consumer-products-TACN
#    marketCapPct  change3m  currentRank  prevRank  securities    weight  \
# 0      0.481799 -0.212989           23        20          49  1.285523
# 1      0.475770  0.184290           12        14         106  1.835041
# 2      0.353369 -0.165597           28        22         237  0.547311
# 3      0.333528 -0.064108           19        18          91  1.443780
# 4      0.314836 -0.301997           35        27          79  0.846507
#
#   meta_mfId     meta_isin                       meta_name  \
# 0   M_HDCTP  INF179K01YV8             HDFC Large Cap Fund
# 1    M_CAOP  INF760K01EI4  Canara Rob Emerg Equities Fund
# 2    M_NIMS  INF204K01K15     Nippon India Small Cap Fund
# 3   M_ADTUE  INF209K01XX1  Aditya Birla SL Flexi Cap Fund
# 4    M_NIGE  INF204K01XI3     Nippon India Large Cap Fund
#
#                                        meta_fullName meta_option
# 0         HDFC Large Cap Fund - Growth - Direct Plan      Growth
# 1  Canara Robeco Emerging Equities - Growth - Dir...      Growth
# 2  Nippon India Small Cap Fund - Growth - Direct ...      Growth
# 3  Aditya Birla Sun Life Flexi Cap Fund - Growth ...      Growth
# 4  Nippon India Large Cap Fund - Growth - Direct ...      Growth

# %% [markdown]
# # SmallCase Holdings of an Equity

# %%
_, raw_data = ttp.get_ticker('Infosys')
slug_url = raw_data[0].get('slug')
print(slug_url)
ttp.get_smallcase_holdings(slug_url)
# Out:
# /stocks/infosys-INFY
#         scid                  name    publisher     publisherName  \
# 0  SCMO_0014  Dividend Aristocrats  smallcaseHQ  Windmill Capital
# 1  SCTR_0006            IT Tracker  smallcaseHQ  Windmill Capital
#
#                                         slug  \
# 0  /smallcase/dividend-aristocrats-SCMO_0014
# 1            /smallcase/it-tracker-SCTR_0006
#
#                                              iconUrl       cagr    weight  \
# 0  https://assets.smallcase.com/images/smallcases...   7.485511  0.091357
# 1  https://assets.smallcase.com/images/smallcases...  16.148352  0.115619
#
#                                          description  minAmount
# 0  Companies that have been consistently increasi...      70143
# 1  Companies to efficiently track and invest in t...     105380

# %% [markdown]
# # Dividends History of an Equity this will provide history as well as confirmed upcoming

# %%
_, raw_data = ttp.get_ticker('ITC ltd')
slug_url = raw_data[0].get('slug')
print(slug_url)
ttp.get_dividends_history(slug_url)
# Out:
# /stocks/itc-ITC
#                         _id   description  dividend                    exDate  \
# 0  665a6dfe05bb6ca068f1f359     Final|7.5  7.095100  2024-06-04T00:00:00.000Z
# 1  65b997d88a2dd7eecd38ac4d  Interim|6.25  5.912583  2024-02-08T00:00:00.000Z
# 2  646c0b7999f7f66b45caa04a    Final|6.75  6.385590  2023-05-30T00:00:00.000Z
# 3  646c0b7999f7f66b45caa04c  Special|2.75  2.601537  2023-05-30T00:00:00.000Z
# 4  63e5926d51bce260ed2944e3     Interim|6  5.676080  2023-02-15T00:00:00.000Z
# 5  6286e29b9ea2727459ab864f    Final|6.25  5.912583  2022-05-26T00:00:00.000Z
#
#    sid          type          title  subType value ticker
# 0  ITC  cashDividend  Cash Dividend    Final   7.5    ITC
# 1  ITC  cashDividend  Cash Dividend  Interim  6.25    ITC
# 2  ITC  cashDividend  Cash Dividend    Final  6.75    ITC
# 3  ITC  cashDividend  Cash Dividend  Special  2.75    ITC
# 4  ITC  cashDividend  Cash Dividend  Interim     6    ITC
# 5  ITC  cashDividend  Cash Dividend    Final  6.25    ITC

# %% [markdown]
# # Key Ratios of a stock or Index

# %%
_, raw_data = ttp.get_ticker('Adani Ports')
slug_url = raw_data[0].get('slug')
print(slug_url)
ttp.get_key_ratios(slug_url)
# Out:
# /stocks/adani-ports-and-special-economic-zone-APSE
#                              0
# risk                  2.877618
# 3mAvgVol        4600974.253968
# 4wpct               -10.894712
# 52wHigh                 1621.4
# 52wLow                  995.65
# 52wpct               -8.411908
# beta                  1.182014
# bps                 253.132097
# divYield              0.539471
# eps                  37.546844
# inddy                 0.599463
# indpb                  6.58432
# indpe                45.343752
# marketCap        240250.653463
# mrktCapRank                 30
# pb                    4.393753
# pe                   29.621664
# roe                  15.946559
# nShareholders          1186670
# lastPrice               1112.2
# ttmPe                24.500622
# marketCapLabel        Largecap
# 12mVol               40.879596
# mrktCapf         240250.653463
# apef                 29.621664
# pbr                   4.393753
# etfLiq                0.017533
# etfLiqLabel               High

# %%
_, raw_data = ttp.get_ticker('NIFTY 50')
slug_url = raw_data[0].get('slug')
print(slug_url)
ttp.get_key_ratios(slug_url)
# Out:
# /indices/nifty-50-index-.NSEI
#                                  0
# marketCapLabel            Largecap
# 52wpct                    8.385333
# 4wpct                    -4.568069
# 52wHigh                   26277.35
# 52wLow                     21137.2
# divYield                   1.20538
# pb                        3.993036
# pe                       23.869136
# 5yYldAvg                  1.361877
# sharpeRatio               1.054187
# constituentsCount               50
# etfsCount                       20
# marketCap          18724964.805983
# marketCapShare            42.59679
# risk                             1
# 12mVol                   14.910784
# lastPrice                  23431.5

# %% [markdown]
# # All ETFs under an Index

# %%
ttp.get_all_etfs_under_index('.NSEI')
# Out:
#      sid  stock_advancedRatios_etfLiq stock_advancedRatios_etfLiqLabel  \
# 0   NBES                     0.080679                             High
# 1   SBFP                     0.423574                             High
# 2   ICNI                     0.606283                             High
# 3   MIRA                     0.853089                             High
# 4   UTIN                     3.078506                             High
# 5   KOTK                     3.741114                             High
# 6   HDFN                     4.135987                             High
# 7   DSPN                     4.601869                             High
# 8   ADIY                     4.820524                             High
# 9   NIFT                    14.940680                             High
# 10  AISN                    29.657318                           Medium
# 11  QUAN                    50.183848                           Medium
# 12   M50                    67.505017                           Medium
# 13  LICO                    73.485567                           Medium
# 14  TATN                    76.899850                           Medium
# 15  INVO                   244.432940                              Low
# 16  NAVI                   256.275175                              Low
# 17  IFCN                   370.501056                              Low
# 18  IDTI                          NaN                              Low
# 19  EETS                          NaN                              Low
#
#     stock_advancedRatios_expenseRatio  stock_advancedRatios_trackErr  \
# 0                              0.0400                       0.033336
# 1                              0.0400                       0.030162
# 2                              0.0259                       0.030162
# 3                              0.0400                       0.030162
# 4                              0.0500                       0.031749
# 5                              0.0400                       0.034924
# 6                              0.0500                       0.028574
# 7                              0.0700                       0.030162
# 8                              0.0600                       0.036511
# 9                              0.0700                       0.039686
# 10                             0.0700                       0.047624
# 11                             0.0900                       0.034924
# 12                             0.0600                       0.034924
# 13                             0.0600                       0.038099
# 14                             0.0700                       0.120646
# 15                             0.1000                       0.034924
# 16                             0.0500                       0.182557
# 17                             0.0900                       0.046036
# 18                             0.5200                       1.054067
# 19                             0.0700                       2.241481
#
#    stock_info_sector                          stock_info_name  \
# 0             Equity           Nippon India ETF Nifty 50 BeES
# 1             Equity                         SBI Nifty 50 ETF
# 2             Equity            ICICI Prudential Nifty 50 ETF
# 3             Equity                 Mirae Asset Nifty 50 ETF
# 4             Equity                         UTI Nifty 50 ETF
# 5             Equity                       Kotak Nifty 50 ETF
# 6             Equity                        HDFC Nifty 50 ETF
# 7             Equity                         DSP Nifty 50 ETF
# 8             Equity                  Aditya BSL Nifty 50 ETF
# 9             Equity               Bajaj Finserv Nifty 50 ETF
# 10            Equity                        Axis Nifty 50 ETF
# 11            Equity                     Quantum Nifty 50 ETF
# 12            Equity                    Motilal Oswal M50 ETF
# 13            Equity                      LIC MF Nifty 50 ETF
# 14            Equity                        Tata Nifty 50 ETF
# 15            Equity               Invesco India Nifty 50 ETF
# 16            Equity                        Navi NIFTY 50 ETF
# 17            Equity                        IDFC Nifty 50 ETF
# 18            Equity  Indiabulls NIFTY50 Exchange Traded Fund
# 19            Equity                   Edelweiss Nifty 50 ETF
#
#    stock_info_ticker stock_info_exchange  \
# 0          NIFTYBEES                 NSE
# 1          SETFNIF50                 NSE
# 2          NIFTYIETF                 NSE
# 3           NIFTYETF                 NSE
# 4         UTINIFTETF                 NSE
# 5             NIFTY1                 NSE
# 6          HDFCNIFTY                 NSE
# 7         NIFTY50ADD                 NSE
# 8           BSLNIFTY                 NSE
# 9          NIFTYBETF                 NSE
# 10         AXISNIFTY                 NSE
# 11            QNIFTY                 NSE
# 12             MOM50                 NSE
# 13        LICNETFN50                 NSE
# 14              NETF                 NSE
# 15        IVZINNIFTY                 NSE
# 16         NAVINIFTY                 NSE
# 17        IDFNIFTYET                 NSE
# 18         IBMFNIFTY                 NSE
# 19          NIFTYEES                 NSE
#
#                                        stock_info_amc  \
# 0          Nippon Life India Asset Management Limited
# 1                        SBI Funds Management Limited
# 2   ICICI Prudential Asset Management Company Limited
# 3   Mirae Asset Investment Managers (India) Privat...
# 4        UTI Asset Management Company Private Limited
# 5     Kotak Mahindra Asset Management Company Limited
# 6               HDFC Asset Management Company Limited
# 7             DSP Investment Managers Private Limited
# 8                   Aditya Birla Sun Life AMC Limited
# 9              Bajaj Finserv Asset Management Limited
# 10                 Axis Asset Management Company Ltd.
# 11   Quantum Asset Management Company Private Limited
# 12     Motilal Oswal Asset Management Company Limited
# 13           LIC Mutual Fund Asset Management Limited
# 14              Tata Asset Management Private Limited
# 15          Invesco Asset Management Company Pvt Ltd.
# 16                                   Navi AMC Limited
# 17                                Bandhan AMC Limited
# 18                     Groww Asset Management Limited
# 19                 Edelweiss Asset Management Limited
#
#                                    stock_info_amcDesc  \
# 0   Nippon India Mutual Fund is one of India’s lea...
# 1   With 30 years of rich experience in fund manag...
# 2   ICICI Prudential Asset Management Company Ltd....
# 3   Mirae Asset Financial Group is one of the key ...
# 4   UTI AMC commenced operations from February 1, ...
# 5   Kotak Mahindra Asset Management Company Limite...
# 6   HDFC Asset Management Company, investment mana...
# 7   DSP Investment Managers is an independent Indi...
# 8   Aditya Birla Sun Life AMC Limited, is a joint ...
# 9                                                 NaN
# 10  Axis Asset Management Company Ltd. is the mutu...
# 11  Quantum Asset Management Company Pvt Ltd. is t...
# 12  Motilal Oswal Asset Management Company Ltd. (M...
# 13  LIC Mutual Fund was established on 20th April ...
# 14  Established in 1994, Tata Asset Management Pri...
# 15  Invesco is an independent investment managemen...
# 16                                                NaN
# 17  IDFC AMC Limited is a subsidiary of the IDFC F...
# 18  Indiabulls Housing Finance Limited ("IHFL") is...
# 19  Edelweiss Asset Management Limited (EAML) is p...
#
#                                stock_info_description stock_info_trIndex  \
# 0   NIPPON INDIA ETF Nifty BeES objective is to pr...              .NSEI
# 1   SBI-ETF Nifty 50 objective is to provide retur...              .NSEI
# 2   ICICI Prudential Nifty iWIN ETF objective is t...              .NSEI
# 3   Mirae Asset Nifty 50 ETF objective is to gener...              .NSEI
# 4   UTI-Nifty ETF objective is to provide returns ...              .NSEI
# 5   Kotak Nifty ETF objective is to provide return...              .NSEI
# 6   HDFC Nifty ETF-Growth objective is to provide ...              .NSEI
# 7   DSP Nifty 50 ETF objective is to provide retur...              .NSEI
# 8   Aditya BSL Nifty ETF objective is to provide r...              .NSEI
# 9   Bajaj Finserv Nifty 50 ETF seeks to replicate ...              .NSEI
# 10  Axis Nifty ETF objective is to provide returns...              .NSEI
# 11  Quantum Nifty ETF objective is to invest in st...              .NSEI
# 12  Motilal Oswal MOSt Shares M50 ETF objective is...              .NSEI
# 13  LIC MF ETF-Nifty 50 objective is to provide re...              .NSEI
# 14  Tata Nifty ETF objective of the scheme is to p...              .NSEI
# 15  Invesco India Nifty ETF objective is to provid...              .NSEI
# 16  Navi NIFTY 50 ETF seeks to replicate the retur...              .NSEI
# 17  The fund seeks to provide returns that, before...              .NSEI
# 18  Indiabulls Nifty50 ETF objective is to provide...              .NSEI
# 19  Edelweiss ETF-Nifty 50 objective is to provide...              .NSEI
#
#    stock_info_trIndexName         stock_info_trIndexSlug stock_info_amcCode  \
# 0          Nifty 50 Index  /indices/nifty-50-index-.NSEI                RMF
# 1          Nifty 50 Index  /indices/nifty-50-index-.NSEI                  L
# 2          Nifty 50 Index  /indices/nifty-50-index-.NSEI                  P
# 3          Nifty 50 Index  /indices/nifty-50-index-.NSEI                MAF
# 4          Nifty 50 Index  /indices/nifty-50-index-.NSEI                108
# 5          Nifty 50 Index  /indices/nifty-50-index-.NSEI                  K
# 6          Nifty 50 Index  /indices/nifty-50-index-.NSEI                  H
# 7          Nifty 50 Index  /indices/nifty-50-index-.NSEI                  D
# 8          Nifty 50 Index  /indices/nifty-50-index-.NSEI                  B
# 9          Nifty 50 Index  /indices/nifty-50-index-.NSEI                189
# 10         Nifty 50 Index  /indices/nifty-50-index-.NSEI                128
# 11         Nifty 50 Index  /indices/nifty-50-index-.NSEI                QMF
# 12         Nifty 50 Index  /indices/nifty-50-index-.NSEI                127
# 13         Nifty 50 Index  /indices/nifty-50-index-.NSEI                LIC
# 14         Nifty 50 Index  /indices/nifty-50-index-.NSEI                  T
# 15         Nifty 50 Index  /indices/nifty-50-index-.NSEI                120
# 16         Nifty 50 Index  /indices/nifty-50-index-.NSEI                PLF
# 17         Nifty 50 Index  /indices/nifty-50-index-.NSEI                  G
# 18         Nifty 50 Index  /indices/nifty-50-index-.NSEI                125
# 19         Nifty 50 Index  /indices/nifty-50-index-.NSEI                EMF
#
#                                    stock_slug
# 0   /etfs/nippon-india-nifty-50-bees-etf-NBES
# 1                 /etfs/sbi-nifty-50-etf-SBFP
# 2    /etfs/icici-prudential-nifty-50-etf-ICNI
# 3         /etfs/mirae-asset-nifty-50-etf-MIRA
# 4                 /etfs/uti-nifty-50-etf-UTIN
# 5               /etfs/kotak-nifty-50-etf-KOTK
# 6                /etfs/hdfc-nifty-50-etf-HDFN
# 7                 /etfs/dsp-nifty-50-etf-DSPN
# 8          /etfs/aditya-bsl-nifty-50-etf-ADIY
# 9       /etfs/bajaj-finserv-nifty-50-etf-NIFT
# 10               /etfs/axis-nifty-50-etf-AISN
# 11            /etfs/quantum-nifty-50-etf-QUAN
# 12       /etfs/motilal-oswal-nifty-50-etf-M50
# 13             /etfs/lic-mf-nifty-50-etf-LICO
# 14               /etfs/tata-nifty-50-etf-TATN
# 15      /etfs/invesco-india-nifty-50-etf-INVO
# 16               /etfs/navi-nifty-50-etf-NAVI
# 17               /etfs/idfc-nifty-50-etf-IFCN
# 18         /etfs/indiabulls-nifty-50-etf-IDTI
# 19          /etfs/edelweiss-nifty-50-etf-EETS

# %% [markdown]
# # Tickertape Filters or Screeners
# - You can pass any number of filters listed below, you can also pass entire filters list.
# - `Sortby` pass the filter name by default it considers the first entry in the filters list
# - In the `number of records`  pass n records else it will give entire stocks list available in exchange (~4k stocks)

# %%
all_filters = ttp.get_equity_screener_all_filters()
all_filters
# Out:
# {'Sub-Sector': 'subindustry',
#  'Market Cap': 'mrktCapf',
#  'Sector': 'sector',
#  'Close Price / 50D SMA': 'lastPrice,sma50d,/',
#  'Close Price / 200D SMA': 'lastPrice,sma200d,/',
#  'Return on Equity': 'roe',
#  'Return on Assets': 'rtnAsts',
#  'Net Profit Margin': 'pftMrg',
#  '5Y Avg Return on Equity': '5Yroe',
#  '5Y Avg Return on Assets': '5YrtnAsts',
#  '5Y Avg Net Profit Margin': '5YpftMrg',
#  '5Y Avg EBITDA Margin': 'opmg',
#  'EBITDA Margin': 'aopm',
#  '5Y Avg Return on Investment': '5Yaroi',
#  'Return on Investment': 'aroi',
#  '5Y Avg Cash Flow Margin': '5YcafCfoaMgn',
#  'Cash Flow Margin': 'cafCfoaMgn',
#  'Cost of Goods Sold': 'balCogs',
#  'ROCE': 'roce',
#  'Close Price': 'lastPrice',
#  '1D Return': 'pr1d',
#  'Daily Volume': 'acVol',
#  '1W Return': 'pr1w',
#  '1M Return vs Nifty': '4wpctN',
#  '3M Average Volume': 'vol3mAvg',
#  '1Y Return vs Nifty': '12mpctN',
#  '6M Return vs Nifty': '6mpctN',
#  '6M Return': '26wpct',
#  '1M Return': '4wpct',
#  '1W Return vs Nifty': 'pr1wN',
#  '% Away From 52W High': '52whd',
#  '% Away From 52W Low': '52wld',
#  '1W Change in Volume': 'vol1wChPct',
#  '1D Change in Volume': 'vol1dChPct',
#  '1Y Return': '52wpct',
#  '1M Average Volume': 'vol1mAvg',
#  '5Y CAGR': '5yCagrPct',
#  'Face value': 'faceValue',
#  'Debt to Equity': 'dbtEqt',
#  'Long Term Debt to Equity': 'ldbtEqt',
#  'Cash Conversion Cycle': 'ccnc',
#  'Quick Ratio': 'aqui',
#  'Current Ratio': 'qcur',
#  'Interest Coverage Ratio': 'aint',
#  'Working Capital Turnover Ratio': 'wcTurnR',
#  'Inventory Turnover Ratio': 'invTurnR',
#  'Asset Turnover Ratio': 'asstTurnR',
#  'Earning Power': 'erngPwrR',
#  'Net Income / Liabilities': 'netIncByLbl',
#  '1Y Historical Revenue Growth': 'rvng',
#  '5Y Historical Revenue Growth': '5YrevChg',
#  '5Y Historical EPS Growth': 'epsGwth',
#  '5Y Historical EBITDA Growth': 'earnings',
#  '1Y Historical EBITDA Growth': 'ebitg',
#  '1Y Hist Op. Cash Flow Growth': 'cfog',
#  '1Y Historical EPS Growth': 'epsg',
#  '3Y Historical Dividend Growth': '3YdivGwth',
#  '5Y Hist Op. Cash Flow Growth': 'cfotr',
#  'PE Ratio': 'apef',
#  'Dividend Yield': 'divDps',
#  'PB Ratio': 'pbr',
#  'PS Ratio': 'ps',
#  'EV/EBITDA Ratio': 'evebitd',
#  'EV / Revenue Ratio': 'evByRev',
#  'EV / Free Cash Flow': 'evCafFcf',
#  'Price / Free Cash Flow': 'lcpCafFcf',
#  'EV / Invested Capital': 'evByIc',
#  'Price / CFO': 'priceCfoR',
#  'Price / Sales': 'priceBySales',
#  'Enterprise Value': 'ev',
#  'EV / EBIT Ratio': 'evebit',
#  'Sector PB': 'indpb',
#  'Sector PE': 'indpe',
#  'Sector Dividend Yield': 'inddy',
#  'TTM PE Ratio': 'ttmPe',
#  'Domestic Institutional Holding': 'domInstHldng',
#  'Mutual Fund Holding': 'instown',
#  'Foreign Institutional Holding': 'forInstHldng',
#  'MF Holding Change\xa0–\xa03M': 'instown3',
#  'Promoter Holding': 'strown',
#  '\xa0MF Holding Change\xa0–\xa06M': 'chMutHldng6M',
#  'FII Holding Change\xa0–\xa03M': 'forInstHldng3M',
#  'DII Holding Change\xa0–\xa03M': 'domInstHldng3M',
#  'DII Holding Change\xa0–\xa06M': 'domInstHldng6M',
#  'Promoter Holding Change\xa0–\xa06M\xa0': 'chPromHldng6M',
#  'FII Holding Change\xa0–\xa06M': 'forInstHldng6M',
#  'Promoter Holding Change\xa0–\xa03M': 'strown3',
#  'Pledged Promoter Holdings': 'promShrPled',
#  'Insurance Firms Holding': 'insHolding',
#  'Retail Investor Holding': 'retailHolding',
#  'No. of Shareholders': 'nShareholders',
#  'Lot Size': 'ftls',
#  'Future Close Price': 'ftcp',
#  'Basis': 'ftbas',
#  'Future Open Interest': 'ftoi',
#  'Call Open Interest': 'opcoi',
#  'Future Volume': 'ftvol',
#  'Put Open Interest': 'oppoi',
#  '% Price above 1M SMA': 'pab1Mma',
#  'Beta': 'beta',
#  '% Price above 1Y SMA': 'pab12Mma',
#  'Relative Volume': 'relVol',
#  '% Price above 1M EMA': 'prAvMonthEVA',
#  'Sharpe Ratio': '3Ywsh',
#  'Alpha': '3Ywal',
#  'Volatility vs Nifty': '12mVolN',
#  'Volatility': '12mVol',
#  'VWAP': 'vWAP',
#  '100D SMA': 'sma100d',
#  '200D SMA': 'sma200d',
#  '200D EMA': 'ema200d',
#  '1Y Max Loss': 'maxDrawdown',
#  '50D EMA': 'ema50d',
#  '10D EMA': 'ema10d',
#  '50D SMA': 'sma50d',
#  '10D SMA': 'sma10d',
#  '100D EMA': 'ema100d',
#  'Interest & Other Items': 'incIoi',
#  'Taxes & Other Items': 'incToi',
#  'Total Revenue': 'incTrev',
#  'Payout Ratio': 'incPyr',
#  'Depreciation & Amortization': 'incDep',
#  'Earnings Per Share': 'incEps',
#  'Net Income': 'incNinc',
#  'PBT': 'incPbt',
#  'Dividend Per Share': 'incDps',
#  'EBITDA': 'incEbi',
#  'PBIT': 'incPbi',
#  'Raw Materials': 'incRaw',
#  'Employee Cost': 'incEpc',
#  'Operating & Other expenses': 'incOpe',
#  'Power & Fuel Cost': 'incPfc',
#  'Selling & Administrative Expenses': 'incSga',
#  'Total revenue (Q)': 'qIncTrevK',
#  'PBT (Q)': 'qIncPbtK',
#  'EBITDA (Q)': 'qIncEbiK',
#  'Operating and Other Expenses (Q)': 'qIncOpeK',
#  'EPS (Q)': 'qIncEpsK',
#  'Net Income (Q)': 'qIncNincK',
#  'PBIT (Q)': 'qIncPbiK',
#  'Total Receivables': 'balTrec',
#  'Share Capital': 'balComs',
#  'Cash and Equivalent': 'balCsti',
#  'Reserves & Surplus': 'balRtne',
#  'Accounts Payable': 'balAccp',
#  'Long Term Investments': 'balLti',
#  'Total Debt': 'balTdeb',
#  'Total Assets': 'balTota',
#  'Total Deposits – Banks': 'balTdep',
#  'Total Current Assets': 'balTca',
#  'Financing Cash Flow': 'cafCffa',
#  'Additional Paid–in Capital': 'balApic',
#  'Total Inventory': 'balTinv',
#  'Total Cash Dividend Paid': 'cafTcdp',
#  'Total Current Liabilities': 'balTcl',
#  'Total Equity': 'balTeq',
#  'Net Property,Plant & Equipment': 'balNppe',
#  'Minority Interest': 'balMint',
#  'Long Term Debt': 'balTltd',
#  'Operating Cash Flow': 'cafCfoa',
#  'Common Shares Outstanding': 'balTcso',
#  'Deferred Tax Liabilities (Net)': 'balDit',
#  'Investing Cash Flow': 'cafCfia',
#  'Net Change in Cash': 'cafNcic',
#  'Change in Working Capital': 'cafCiwc',
#  'Loans & Advances': 'balNetl',
#  'Total Liabilities': 'balTotl',
#  'Goodwill & Intangibles': 'balGint',
#  'Capital Expenditure': 'cafCexp',
#  'Non Current Liabilties': 'balNcl',
#  'Non Current Assets': 'balNca',
#  'Free Cash Flow': 'cafFcf',
#  'Deferred Tax Assets (Net)': 'balDta',
#  'Book Value': 'bookValue',
#  'Other Liabilities': 'balOthl',
#  'Other Current Liabilities': 'balOcl',
#  'Other Assets': 'balOtha',
#  'Other Current Assets': 'balOca',
#  'Expense Ratio': 'expenseRatio',
#  'Tracking Error': 'trackErr'}

# %%
filtered_list_df = ttp.get_equity_screener_data(filters=["mrktCapf", "lastPrice", "beta"], sortby='mrktCapf', number_of_records=20)
filtered_list_df.head()
# Out:
#    advancedRatios.lastPrice  advancedRatios.beta  advancedRatios.mrktCapf  \
# 0                   1241.90             1.001020             1.680585e+06
# 1                   4265.65             0.601417             1.543350e+06
# 2                   1656.75             1.095953             1.267132e+06
# 3                   1615.90             0.615092             9.668636e+05
# 4                   1249.85             1.261440             8.823835e+05
#
#                        info.name info.ticker             info.sector   sid
# 0        Reliance Industries Ltd    RELIANCE                  Energy  RELI
# 1  Tata Consultancy Services Ltd         TCS  Information Technology   TCS
# 2                  HDFC Bank Ltd    HDFCBANK              Financials  HDBK
# 3              Bharti Airtel Ltd  BHARTIARTL  Communication Services  BRTI
# 4                 ICICI Bank Ltd   ICICIBANK              Financials  ICBK
