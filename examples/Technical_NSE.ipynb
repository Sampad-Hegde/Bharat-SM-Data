# %%
from Technical import NSE
import pandas as pd
import requests
from io import StringIO

# %%
nse = NSE()

# %%
# Some NSE basic functions this is available any NSE Object (Technical OR Derivatives)
# searching
search_res = nse.search('Syrma SGS')
print(search_res.get('symbols')[0].get('symbol'))

# Last Traded date
print(nse.get_last_traded_date())

# Last traded Status and Nifty val
print(nse.get_market_status_and_current_val())

# NSE Equity Meta info
print(nse.get_nse_equity_meta_info('SYRMA'))
# Out:
# SYRMA
# 2025-01-10
# ('Close', 23431.5)
# {'symbol': 'SYRMA', 'companyName': 'Syrma SGS Technology Limited', 'industry': 'Industrial Products', 'activeSeries': ['EQ'], 'debtSeries': [], 'isFNOSec': False, 'isCASec': False, 'isSLBSec': True, 'isDebtSec': False, 'isSuspended': False, 'tempSuspendedSeries': [], 'isETFSec': False, 'isDelisted': False, 'isin': 'INE0DYJ01015', 'slb_isin': 'INE0DYJ01015', 'listingDate': '2022-08-26', 'isMunicipalBond': False, 'quotepreopenstatus': {'equityTime': '10-Jan-2025 16:00:00', 'preOpenTime': '10-Jan-2025 09:07:46', 'QuotePreOpenFlag': False}}

# %%
imp_reports_link = nse.get_important_reports()
imp_reports_link[:5]
# Out:
# [{'name': 'CM-UDiFF Common Bhavcopy Final (zip)',
#   'type': 'daily-reports',
#   'category': 'capital-market',
#   'section': 'equities',
#   'link': 'https://nsearchives.nseindia.com/content/cm/BhavCopy_NSE_CM_0_0_0_20250110_F_0000.csv.zip'},
#  {'name': 'CM - Market Activity Report',
#   'type': 'daily-reports',
#   'category': 'capital-market',
#   'section': 'equities',
#   'link': 'https://nsearchives.nseindia.com/archives/equities/mkt/MA100125.csv'},
#  {'name': 'CM - Security-wise Delivery Positions',
#   'type': 'daily-reports',
#   'category': 'capital-market',
#   'section': 'equities',
#   'link': 'https://nsearchives.nseindia.com/archives/equities/mto/MTO_10012025.DAT'},
#  {'name': 'CM - List of securities for auction',
#   'type': 'daily-reports',
#   'category': 'capital-market',
#   'section': 'equities',
#   'link': 'https://nsearchives.nseindia.com/content/nsccl/AUB_2025007_10012025.csv'},
#  {'name': 'CM - Category-wise Turnover',
#   'type': 'daily-reports',
#   'category': 'capital-market',
#   'section': 'equities',
#   'link': 'https://nsearchives.nseindia.com/archives/equities/cat/cat_turnover_100125.xls'}]

# %%
# Let's say you need report of `CM - Security-wise Delivery Positions`
report_link = imp_reports_link[3].get('link')
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept': 'text/csv'
}
response = requests.get(report_link, headers=headers, timeout=15)
pd.read_csv(StringIO(response.text)).head()
# Out:
#                         Confirmed list of securities to be auctioned in A 2025007 to be held on Jan 10 2025.
# Sr No Symbol     Series                                          Total Qty
# 1     AARTECH    EQ                                                     26
# 2     ABCAPITAL  EQ                                                      6
# 3     ABSLAMC    EQ                                                     13
# 4     ABSLBANETF EQ                                                     21

# %%
# NSE turnover data
trade_df = nse.get_nse_turnover()
trade_df.head()
# Out:
#           instrument      volume                value oivalue  noOfOrders  \
# 0    <b>Equities</b>       &nbsp                &nbsp   &nbsp       &nbsp
# 1             Equity  3109534900  930035772180.569946       0
# 2                SME    14758963         3516208083.6       0
# 3             Others     1322420         283562529.32       0
# 4  <span>Total<span>  3125616283   933835542793.48999          1171999081
#
#   noOfTrades mktTimeStamp averageTrade  prevVolume            prevValue  ...  \
# 0      &nbsp        &nbsp        &nbsp       &nbsp                &nbsp  ...
# 1   40720680        16:00        22839  2710963703  888724122404.079956  ...
# 2      15315        16:00       229592    15468374         3084484808.3  ...
# 3       3292        16:00        86137     1283908         262981875.85  ...
# 4   40739287        &nbsp          NaN  2727715985   892071589088.22998  ...
#
#   segment notionalTurnover  premiumTurnover  prevInstrument  \
# 0     NaN              NaN              NaN             NaN
# 1      CM     9.300358e+11              0.0          EQUITY
# 2      CM     3.516208e+09              0.0             SME
# 3      CM     2.835625e+08              0.0          OTHERS
# 4   total              NaN              NaN             NaN
#
#   prevNotionalTurnover  prevPremiumTurnover  prevNoOfTrades  \
# 0                  NaN                  NaN             NaN
# 1         8.887241e+11                  0.0      34759731.0
# 2         3.084485e+09                  0.0         14310.0
# 3         2.629819e+08                  0.0          2853.0
# 4                  NaN                  NaN             NaN
#
#         prevMktTimeStamp prevAverageTrade  prevNoOfOrders
# 0                    NaN              NaN             NaN
# 1  2025-01-09 16:00:00.0              NaN    1.171999e+09
# 2  2025-01-09 16:00:00.0              NaN    1.171999e+09
# 3  2025-01-09 16:00:00.0              NaN    1.171999e+09
# 4                    NaN              NaN             NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# ## All Indices in NSE Exchange

# %%
nse.get_all_indices()
# Out:
#                       key                                 index  \
# 0    BROAD MARKET INDICES                              NIFTY 50
# 1    BROAD MARKET INDICES                         NIFTY NEXT 50
# 2    BROAD MARKET INDICES                             NIFTY 100
# 3    BROAD MARKET INDICES                             NIFTY 200
# 4    BROAD MARKET INDICES                             NIFTY 500
# ..                    ...                                   ...
# 116  FIXED INCOME INDICES  NIFTY BHARAT BOND INDEX - APRIL 2025
# 117  FIXED INCOME INDICES  NIFTY BHARAT BOND INDEX - APRIL 2030
# 118  FIXED INCOME INDICES  NIFTY BHARAT BOND INDEX - APRIL 2031
# 119  FIXED INCOME INDICES  NIFTY BHARAT BOND INDEX - APRIL 2032
# 120  FIXED INCOME INDICES  NIFTY BHARAT BOND INDEX - APRIL 2033
#
#           indexSymbol      last  variation  percentChange      open      high  \
# 0            NIFTY 50  23431.50     -95.00          -0.40  23551.90  23596.60
# 1       NIFTY NEXT 50  64257.10   -1300.10          -1.98  65544.35  65662.45
# 2           NIFTY 100  24064.75    -167.55          -0.69  24252.80  24288.75
# 3           NIFTY 200  13105.35    -123.15          -0.93  13234.20  13251.70
# 4           NIFTY 500  21799.00    -247.55          -1.12  22049.40  22075.40
# ..                ...       ...        ...            ...       ...       ...
# 116  BHARATBOND-APR25   1291.69       0.26           0.02   1291.65   1291.69
# 117  BHARATBOND-APR30   1451.42      -0.76          -0.05   1452.47   1452.47
# 118  BHARATBOND-APR31   1324.22       0.26           0.01   1324.22   1324.22
# 119  BHARATBOND-APR32   1210.08       0.23           0.01   1210.08   1210.08
# 120  BHARATBOND-APR33   1180.54       0.23           0.01   1180.55   1180.55
#
#           low  previousClose  ...  date365dAgo  \
# 0    23344.35       23526.50  ...  11-Jan-2024
# 1    64126.25       65557.20  ...  11-Jan-2024
# 2    23982.90       24232.30  ...  11-Jan-2024
# 3    13070.10       13228.50  ...  11-Jan-2024
# 4    21738.45       22046.55  ...  11-Jan-2024
# ..        ...            ...  ...          ...
# 116   1291.64        1291.43  ...            -
# 117   1451.42        1452.18  ...            -
# 118   1324.21        1323.96  ...            -
# 119   1210.08        1209.85  ...            -
# 120   1180.54        1180.31  ...            -
#
#                                          chart365dPath   date30dAgo  \
# 0    https://nsearchives.nseindia.com/365d/NIFTY-50...  11-Dec-2024
# 1    https://nsearchives.nseindia.com/365d/NIFTY-NE...  11-Dec-2024
# 2    https://nsearchives.nseindia.com/365d/NIFTY-10...  11-Dec-2024
# 3    https://nsearchives.nseindia.com/365d/NIFTY-20...  11-Dec-2024
# 4    https://nsearchives.nseindia.com/365d/NIFTY-50...  11-Dec-2024
# ..                                                 ...          ...
# 116                                                  -  11-Dec-2024
# 117                                                  -  11-Dec-2024
# 118                                                  -  11-Dec-2024
# 119                                                  -  11-Dec-2024
# 120                                                  -  11-Dec-2024
#
#     perChange30d                                       chart30dPath  \
# 0          -4.91  https://nsearchives.nseindia.com/30d/NIFTY-50.svg
# 1         -12.33  https://nsearchives.nseindia.com/30d/NIFTY-NEX...
# 2          -6.13  https://nsearchives.nseindia.com/30d/NIFTY-100...
# 3          -6.44  https://nsearchives.nseindia.com/30d/NIFTY-200...
# 4          -6.67  https://nsearchives.nseindia.com/30d/NIFTY-500...
# ..           ...                                                ...
# 116         0.55  https://nsearchives.nseindia.com/30d/BHARATBON...
# 117         0.18  https://nsearchives.nseindia.com/30d/BHARATBON...
# 118         0.20  https://nsearchives.nseindia.com/30d/BHARATBON...
# 119         0.29  https://nsearchives.nseindia.com/30d/BHARATBON...
# 120         0.39  https://nsearchives.nseindia.com/30d/BHARATBON...
#
#                                         chartTodayPath previousDay oneWeekAgo  \
# 0    https://nsearchives.nseindia.com/today/NIFTY-5...    23688.95   24004.75
# 1    https://nsearchives.nseindia.com/today/NIFTY-N...    66402.60   69192.45
# 2    https://nsearchives.nseindia.com/today/NIFTY-1...    24426.00   24879.85
# 3    https://nsearchives.nseindia.com/today/NIFTY-2...    13337.50   13610.50
# 4    https://nsearchives.nseindia.com/today/NIFTY-5...    22231.80   22708.15
# ..                                                 ...         ...        ...
# 116  https://nsearchives.nseindia.com/today/BHARATB...     1291.36    1290.12
# 117  https://nsearchives.nseindia.com/today/BHARATB...     1452.01    1449.91
# 118  https://nsearchives.nseindia.com/today/BHARATB...     1324.01    1322.53
# 119  https://nsearchives.nseindia.com/today/BHARATB...     1209.26    1208.02
# 120  https://nsearchives.nseindia.com/today/BHARATB...     1179.64    1179.25
#
#     oneMonthAgo oneYearAgo
# 0      24610.05   21618.70
# 1      73096.45   54077.65
# 2      25600.20   21885.80
# 3      13985.45   11820.45
# 4      23314.90   19517.85
# ..          ...        ...
# 116     1284.41        NaN
# 117     1449.40        NaN
# 118     1321.97        NaN
# 119     1206.70        NaN
# 120     1175.86        NaN
#
# [121 rows x 30 columns]

# %% [markdown]
# ### Get All Equities from an index

# %%
# default it takes `SECURITIES IN F&O`
# This supports all options in this drop down` https://www.nseindia.com/market-data/live-equity-market`
index_df = nse.get_equities_data_from_index()
index_df.head()

index_df = nse.get_equities_data_from_index(index='NIFTY SMALLCAP 100')
index_df.head()
# Out:
#    priority              symbol          identifier      open   dayHigh  \
# 0         1  NIFTY SMALLCAP 100  NIFTY SMALLCAP 100  18100.50  18115.05
# 1         0             RKFORGE          RKFORGEEQN    904.10    998.00
# 2         0             SWSOLAR          SWSOLAREQN    436.65    465.00
# 3         0               AMBER            AMBEREQN   7750.00   8098.70
# 4         0               BSOFT            BSOFTEQN    542.00    556.70
#
#      dayLow  lastPrice  previousClose  change  pChange  ...  perChange30d  \
# 0  17628.95   17645.55       18118.35 -472.80    -2.61  ...        -10.23
# 1    897.50     959.00         903.70   55.30     6.12  ...          -1.9
# 2    425.25     447.00         438.65    8.35     1.90  ...        -11.94
# 3   7703.05    7850.00        7703.95  146.05     1.90  ...         35.18
# 4    541.05     552.25         543.45    8.80     1.62  ...        -10.11
#
#    series  meta_symbol                              meta_companyName  \
# 0     NaN          NaN                                           NaN
# 1      EQ      RKFORGE                   Ramkrishna Forgings Limited
# 2      EQ      SWSOLAR  Sterling and Wilson Renewable Energy Limited
# 3      EQ        AMBER               Amber Enterprises India Limited
# 4      EQ        BSOFT                             BIRLASOFT LIMITED
#
#                        meta_industry  meta_slb_isin meta_listingDate  \
# 0                                NaN            NaN              NaN
# 1       Auto Components & Equipments   INE399G01023       2004-05-05
# 2                 Civil Construction   INE00M201021       2019-08-20
# 3               Household Appliances   INE371P01015       2018-01-30
# 4  Computers - Software & Consulting   INE836A01035       1999-11-24
#
#    meta_quotepreopenstatus_equityTime  meta_quotepreopenstatus_preOpenTime  \
# 0                                 NaN                                  NaN
# 1                10-Jan-2025 16:00:00                 10-Jan-2025 09:07:46
# 2                10-Jan-2025 16:00:00                 10-Jan-2025 09:07:46
# 3                10-Jan-2025 16:00:00                 10-Jan-2025 09:07:46
# 4                10-Jan-2025 16:00:00                 10-Jan-2025 09:07:46
#
#   meta_quotepreopenstatus_QuotePreOpenFlag
# 0                                      NaN
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
# [5 rows x 32 columns]

# %%
# OHLC Data
nse.get_ohlc_data('EASEMYTRIP', is_index=False)
# Out:
#                       open   high    low  close
# timestamp
# 2025-01-10 09:00:00  14.95  15.15  14.95  15.11
# 2025-01-10 09:05:00  15.11  15.12  15.11  15.12
# 2025-01-10 09:10:00    NaN    NaN    NaN    NaN
# 2025-01-10 09:15:00  15.13  15.15  14.95  14.95
# 2025-01-10 09:20:00  14.93  14.99  14.86  14.95
# ...                    ...    ...    ...    ...
# 2025-01-10 15:35:00    NaN    NaN    NaN    NaN
# 2025-01-10 15:40:00  14.82  14.82  14.82  14.82
# 2025-01-10 15:45:00  14.82  14.82  14.82  14.82
# 2025-01-10 15:50:00  14.82  14.82  14.82  14.82
# 2025-01-10 15:55:00  14.82  14.82  14.82  14.82
#
# [84 rows x 4 columns]

# %% [markdown]
# ## Trade Info Data

# %%
nse.get_trade_info('CENTRALBK').T
# Out:
#                                                                                        0
# currentMarketType                                                                     NM
# noBlockDeals                                                                        True
# bulkBlockDeals                           [{'name': 'Session I'}, {'name': 'Session II'}]
# info_symbol                                                                    CENTRALBK
# info_companyName                                                   Central Bank of India
# ...                                                                                  ...
# securityWiseDP_quantityTraded                                                    4071493
# securityWiseDP_deliveryQuantity                                                  1286049
# securityWiseDP_deliveryToTradedQuantity                                            31.59
# securityWiseDP_seriesRemarks                                                        None
# securityWiseDP_secWiseDelPosDate                                         10-JAN-2025 EOD
#
# [114 rows x 1 columns]

# %% [markdown]
# ## Corporate Disclosures

# %%
nse.get_corporate_disclosures('EASEMYTRIP')
# Out:
# {'EASEMYTRIP': {'latest_announcements': {'data': [{'symbol': 'EASEMYTRIP',
#      'broadcastdate': '10-Jan-2025 17:21:27',
#      'subject': 'News Verification'},
#     {'symbol': 'EASEMYTRIP',
#      'broadcastdate': '09-Jan-2025 16:47:10',
#      'subject': 'Shareholders meeting'},
#     {'symbol': 'EASEMYTRIP',
#      'broadcastdate': '08-Jan-2025 12:24:35',
#      'subject': 'Change in Directors/ Key Managerial Personnel/ Auditor/ Compliance Officer/ Share Transfer Agent'},
#     {'symbol': 'EASEMYTRIP',
#      'broadcastdate': '07-Jan-2025 13:54:14',
#      'subject': 'Copy of Newspaper Publication'},
#     {'symbol': 'EASEMYTRIP',
#      'broadcastdate': '06-Jan-2025 17:00:01',
#      'subject': 'Shareholders meeting'},
#     {'symbol': 'EASEMYTRIP',
#      'broadcastdate': '06-Jan-2025 16:32:40',
#      'subject': 'News Verification'},
#     {'symbol': 'EASEMYTRIP',
#      'broadcastdate': '06-Jan-2025 15:48:27',
#      'subject': 'Certificate under SEBI (Depositories and Participants) Regulations, 2018'},
#     {'symbol': 'EASEMYTRIP',
#      'broadcastdate': '01-Jan-2025 10:59:59',
#      'subject': 'Press Release'}]},
#   'corporate_actions': {'data': [{'symbol': 'EASEMYTRIP',
#      'exdate': '29-Nov-2024',
#      'purpose': 'Bonus 1:1'},
#     {'symbol': 'EASEMYTRIP',
#      'exdate': '19-Dec-2023',
#      'purpose': 'Interim Dividend - Re 0.10 Per Share'},
#     {'symbol': 'EASEMYTRIP',
#      'exdate': '21-Nov-2022',
#      'purpose': 'Face Value Split (Sub-Division) - From Rs 2/- Per Share To Re 1/- Per Share'},
#     {'symbol': 'EASEMYTRIP', 'exdate': '21-Nov-2022', 'purpose': 'Bonus 3:1'},
#     {'symbol': 'EASEMYTRIP', 'exdate': '28-Feb-2022', 'purpose': 'Bonus 1:1'},
#     {'symbol': 'EASEMYTRIP',
#      'exdate': '18-Nov-2021',
#      'purpose': ' Interim Dividend - Re 1  Per Share'},
#     {'symbol': 'EASEMYTRIP',
#      'exdate': '27-Apr-2021',
#      'purpose': ' Interim Dividend - Rs 2 Per Share'}]},
#   'shareholdings_patterns': {'data': {'31-Dec-2023': [{'Promoter & Promoter Group': '  64.30'},
#      {'Public': '  35.70'},
#      {'Shares held by Employee Trusts': '   0.00'},
#      {'Total': ' 100.00'}],
#     '31-Mar-2024': [{'Promoter & Promoter Group': '  64.30'},
#      {'Public': '  35.70'},
#      {'Shares held by Employee Trusts': '   0.00'},
#      {'Total': ' 100.00'}],
#     '30-Jun-2024': [{'Promoter & Promoter Group': '  64.30'},
#      {'Public': '  35.70'},
#      {'Shares held by Employee Trusts': '   0.00'},
#      {'Total': ' 100.00'}],
#     '30-Sep-2024': [{'Promoter & Promoter Group': '  50.38'},
#      {'Public': '  49.62'},
#      {'Shares held by Employee Trusts': '   0.00'},
#      {'Total': ' 100.00'}],
#     '31-Dec-2024': [{'Promoter & Promoter Group': '  50.38'},
#      {'Public': '  49.62'},
#      {'Shares held by Employee Trusts': '   0.00'},
#      {'Total': ' 100.00'}]}},
#   'financial_results': {'data': [{'from_date': '01 Jul 2024',
#      'to_date': '30 Sep 2024',
#      'expenditure': '7140.9',
#      'income': '10917.8',
#      'audited': 'Un-Audited',
#      'cumulative': 'Non-cumulative',
#      'consolidated': 'Non-Consolidated',
#      'reDilEPS': '0.18',
#      'reProLossBefTax': '3776.9',
#      'proLossAftTax': '2779.6',
#      're_broadcast_timestamp': '14-Nov-2024 21:18',
#      'xbrl_attachment': 'https://nsearchives.nseindia.com/corporate/xbrl/INDAS_116396_1313342_14112024091855.xml',
#      'na_attachment': 'https://nsearchives.nseindia.com/na_attachments/EASEMYTRIP_NA_14112024211855_1.zip'},
#     {'from_date': '01 Apr 2024',
#      'to_date': '30 Jun 2024',
#      'expenditure': '6354.3',
#      'income': '10963.7',
#      'audited': 'Un-Audited',
#      'cumulative': 'Non-cumulative',
#      'consolidated': 'Non-Consolidated',
#      'reDilEPS': '0.19',
#      'reProLossBefTax': '4609.4',
#      'proLossAftTax': '3429.1',
#      're_broadcast_timestamp': '13-Aug-2024 18:41',
#      'xbrl_attachment': 'https://nsearchives.nseindia.com/corporate/xbrl/INDAS_111852_1223997_13082024064130.xml',
#      'na_attachment': 'https://nsearchives.nseindia.com/na_attachments/EASEMYTRIP_NA_13082024184130_1.zip'},
#     {'from_date': '01 Jan 2024',
#      'to_date': '31 Mar 2024',
#      'expenditure': '7739.4',
#      'income': '13729.8',
#      'audited': 'Audited',
#      'cumulative': 'Non-cumulative',
#      'consolidated': 'Non-Consolidated',
#      'reDilEPS': '-0.05',
#      'reProLossBefTax': '-1252.7',
#      'proLossAftTax': '-957.7',
#      're_broadcast_timestamp': '24-May-2024 18:06',
#      'xbrl_attachment': 'https://nsearchives.nseindia.com/corporate/xbrl/INDAS_107061_1137771_24052024060617.xml',
#      'na_attachment': 'https://nsearchives.nseindia.com/na_attachments/EASEMYTRIP_NA_24052024180617_1.zip'},
#     {'from_date': '01 Oct 2023',
#      'to_date': '31 Dec 2023',
#      'expenditure': '6509.2',
#      'income': '13328.3',
#      'audited': 'Un-Audited',
#      'cumulative': 'Non-cumulative',
#      'consolidated': 'Non-Consolidated',
#      'reDilEPS': '0.29',
#      'reProLossBefTax': '6819.1',
#      'proLossAftTax': '5112.2',
#      're_broadcast_timestamp': '09-Feb-2024 17:59',
#      'xbrl_attachment': 'https://nsearchives.nseindia.com/corporate/xbrl/INDAS_103127_1050192_09022024055957.xml',
#      'na_attachment': 'https://nsearchives.nseindia.com/na_attachments/EASEMYTRIP_NA_09022024175957_1.zip'},
#     {'from_date': '01 Jul 2023',
#      'to_date': '30 Sep 2023',
#      'expenditure': '5421.8',
#      'income': '12348.1',
#      'audited': 'Un-Audited',
#      'cumulative': 'Non-cumulative',
#      'consolidated': 'Non-Consolidated',
#      'reDilEPS': '0.3',
#      'reProLossBefTax': '6926.3',
#      'proLossAftTax': '5146.4',
#      're_broadcast_timestamp': '09-Nov-2023 10:45',
#      'xbrl_attachment': 'https://nsearchives.nseindia.com/corporate/xbrl/INDAS_99664_981861_09112023104555.xml',
#      'na_attachment': 'https://nsearchives.nseindia.com/na_attachments/EASEMYTRIP_NA_09112023104555_1.zip'}]},
#   'borad_meeting': {'data': [{'symbol': 'EASEMYTRIP',
#      'purpose': 'EASY TRIP PLANNERS LIMITED has informed the Exchange about Board Meeting to be held on 08-Dec-2024 to consider Other business.',
#      'meetingdate': '08-Dec-2024'},
#     {'symbol': 'EASEMYTRIP',
#      'purpose': 'To consider the preferential issue',
#      'meetingdate': '08-Dec-2024'},
#     {'symbol': 'EASEMYTRIP',
#      'purpose': 'To consider the proposal of acquisition.',
#      'meetingdate': '15-Nov-2024'},
#     {'symbol': 'EASEMYTRIP',
#      'purpose': 'EASY TRIP PLANNERS LIMITED has informed the Exchange about Board Meeting to be held on 14-Nov-2024 to inter-alia consider and approve the Unaudited Financial results of the Company for the Half Yearly ended September 2024 .',
#      'meetingdate': '14-Nov-2024'},
#     {'symbol': 'EASEMYTRIP',
#      'purpose': 'To consider and approve the financial results for the period ended September 30, 2024',
#      'meetingdate': '14-Nov-2024'},
#     {'symbol': 'EASEMYTRIP',
#      'purpose': 'Board Meeting Intimation',
#      'meetingdate': '14-Oct-2024'},
#     {'symbol': 'EASEMYTRIP',
#      'purpose': 'To consider bonus',
#      'meetingdate': '14-Oct-2024'},
#     {'symbol': 'EASEMYTRIP',
#      'purpose': 'EASEMYTRIP : 17-Sep-2024 :  The Company has informed the Exchange that a Board meeting to be held on September 13, 2024 has been re-scheduled. Further, the Company has informed the Exchange that the meeting of the Board of Directors of the Company will be held on September 17, 2024,  To consider other business matters',
#      'meetingdate': '13-Sep-2024'}]}}}

# %% [markdown]
# ## SME Data

# %%
# Get SME (Small Medium Enterprises) stocks data
nse.get_sme_stocks()
# Out:
#          symbol series    open  dayHigh  dayLow  lastPrice  change    pChange  \
# 0    MACOBSTECH     SM  166.50   182.00  164.95     179.00   20.00  12.578616
# 1        MAGSON     SM  102.00   109.00  102.00     108.00   11.00  11.340206
# 2    PARAMATRIX     SM  106.00   111.00   94.35     101.80    9.30  10.054054
# 3          VIAZ     SM   65.00    70.50   63.00      70.50    3.40   5.067064
# 4    SHREEKARNI     SM  811.65   811.65  791.50     811.65   38.65   5.000000
# ..          ...    ...     ...      ...     ...        ...     ...        ...
# 355     PROLIFE     SM  290.00   290.00  290.00     290.00  -24.95  -7.921892
# 356        PCCL     SM  198.25   198.25  178.50     180.00  -15.50  -7.928389
# 357     AMIABLE     SM   90.20    90.20   86.00      86.00   -8.00  -8.510638
# 358     SWASTIK     SM   63.90    64.25   57.35      57.35   -7.45 -11.496914
# 359    MICROPRO     SM   32.20    32.55   30.20      30.20   -4.25 -12.336720
#
#      previousClose  stockIndClosePrice  ...    nearWKH     nearWKL  ca  \
# 0           159.00                   0  ...   9.137056  -89.920424
# 1            97.00                   0  ...  18.796992  -42.105263
# 2            92.50                   0  ...  23.516153  -18.234611
# 3            67.10                   0  ...   4.081633  -59.322034
# 4           773.00                   0  ...   4.399293 -212.173077
# ..             ...                 ...  ...        ...         ...  ..
# 355         314.95                   0  ...  19.667590  -55.080214
# 356         195.50                   0  ...  52.978056   -0.840336
# 357          94.00                   0  ...  16.464303  -42.148760
# 358          64.80                   0  ...  47.337006  -13.564356
# 359          34.45                   0  ...  52.627451   -0.332226
#
#                                         chartTodayPath  perChange365d  \
# 0    https://nsearchives.nseindia.com/today/MACOBST...              -
# 1    https://nsearchives.nseindia.com/today/MAGSONS...          -7.41
# 2    https://nsearchives.nseindia.com/today/PARAMAT...              -
# 3    https://nsearchives.nseindia.com/today/VIAZSMN...              -
# 4    https://nsearchives.nseindia.com/today/SHREEKA...              -
# ..                                                 ...            ...
# 355  https://nsearchives.nseindia.com/today/PROLIFE...           8.59
# 356  https://nsearchives.nseindia.com/today/PCCLSMN...              -
# 357  https://nsearchives.nseindia.com/today/AMIABLE...           5.42
# 358  https://nsearchives.nseindia.com/today/SWASTIK...         -38.79
# 359  https://nsearchives.nseindia.com/today/MICROPR...         -46.07
#
#      date365dAgo                                      chart365dPath  \
# 0              -                                                  -
# 1    11-Jan-2024  https://nsearchives.nseindia.com/365d/MAGSON-S...
# 2              -                                                  -
# 3              -                                                  -
# 4              -                                                  -
# ..           ...                                                ...
# 355  11-Jan-2024  https://nsearchives.nseindia.com/365d/PROLIFE-...
# 356            -                                                  -
# 357  11-Jan-2024  https://nsearchives.nseindia.com/365d/AMIABLE-...
# 358  11-Jan-2024  https://nsearchives.nseindia.com/365d/SWASTIK-...
# 359  11-Jan-2024  https://nsearchives.nseindia.com/365d/MICROPRO...
#
#       date30dAgo perChange30d  \
# 0    11-Dec-2024         2.34
# 1    10-Dec-2024        15.56
# 2    11-Dec-2024          1.9
# 3    11-Dec-2024         1.59
# 4    11-Dec-2024        23.68
# ..           ...          ...
# 355  11-Dec-2024         8.21
# 356  11-Dec-2024        -20.1
# 357  11-Dec-2024         1.76
# 358  11-Dec-2024         3.39
# 359  11-Dec-2024       -14.03
#
#                                           chart30dPath
# 0    https://nsearchives.nseindia.com/30d/MACOBSTEC...
# 1    https://nsearchives.nseindia.com/30d/MAGSON-SM...
# 2    https://nsearchives.nseindia.com/30d/PARAMATRI...
# 3     https://nsearchives.nseindia.com/30d/VIAZ-SM.svg
# 4    https://nsearchives.nseindia.com/30d/SHREEKARN...
# ..                                                 ...
# 355  https://nsearchives.nseindia.com/30d/PROLIFE-S...
# 356   https://nsearchives.nseindia.com/30d/PCCL-SM.svg
# 357  https://nsearchives.nseindia.com/30d/AMIABLE-S...
# 358  https://nsearchives.nseindia.com/30d/SWASTIK-S...
# 359  https://nsearchives.nseindia.com/30d/MICROPRO-...
#
# [360 rows x 24 columns]

# %% [markdown]
# ## SGB Data

# %%
# Get SGB (Sovereign Gold Bond) data
nse.get_sgb_data()
# Out:
#         symbol     open     high      low issue_price   ltP     chn    per  \
# 0    SGBNOV258     8092     8092     8041        2911  8092      92   1.15
# 1   SGBOCT27VI  7916.16     8100  7916.16           0  8100      90   1.12
# 2     SGBOCT25        0        0        0        2906  8155    87.5   1.08
# 3   SGBDC27VII     8113     8200     8110           0  8200      87   1.07
# 4   SGBFEB29XI   8111.1     8199   8111.1           0  8199      74   0.91
# ..         ...      ...      ...      ...         ...   ...     ...    ...
# 56  SGBJUN29II  8075.01  8148.99  8075.01           0  8103   -49.5  -0.61
# 57    SGBOCT26     7995     7995     7995        3096  7995  -54.99  -0.68
# 58  SGBSEP31II   8366.9     8400     8300           0  8300  -66.93  -0.80
# 59  SGBJAN30IX     8127     8250     8127           0  8152  -74.15  -0.90
# 60  SGBDE30III  8385.05  8385.05  8276.18           0  8290  -95.05  -1.13
#
#      qty       trdVal  ...    nearWKH    nearWKL maturityDate  \
# 0     30       242658  ...   1.915152 -31.129477        OV258
# 1      5     40316.15  ...   2.994012 -33.507607        T27VI
# 2      0            0  ...   6.199678 -31.638418        OCT25
# 3     27    219319.92  ...   5.747126 -32.686084        27VII
# 4     13    105555.19  ...   4.707113 -33.295399        B29XI
# ..   ...          ...  ...        ...        ...          ...
# 56   109    883474.43  ...   5.117096 -31.949194        N29II
# 57     1         7995  ...   4.366029 -28.951613        OCT26
# 58  1432  11953920.72  ...   3.924065 -34.739822        P31II
# 59   142      1160992  ...  12.410014 -32.552846        N30IX
# 60   110     913254.1  ...   6.749051 -35.346939        30III
#
#                                        chartTodayPath  perChange365d  \
# 0   https://nsearchives.nseindia.com/today/SGBNOV2...          27.49
# 1   https://nsearchives.nseindia.com/today/SGBOCT2...          26.84
# 2   https://nsearchives.nseindia.com/today/SGBOCT2...          26.05
# 3   https://nsearchives.nseindia.com/today/SGBDC27...          29.81
# 4   https://nsearchives.nseindia.com/today/SGBFEB2...          29.17
# ..                                                ...            ...
# 56  https://nsearchives.nseindia.com/today/SGBJUN2...             29
# 57  https://nsearchives.nseindia.com/today/SGBOCT2...          27.98
# 58  https://nsearchives.nseindia.com/today/SGBSEP3...          32.59
# 59  https://nsearchives.nseindia.com/today/SGBJAN3...          30.37
# 60  https://nsearchives.nseindia.com/today/SGBDE30...          33.18
#
#     date365dAgo                                      chart365dPath  \
# 0   09-Jan-2024  https://nsearchives.nseindia.com/365d/SGBNOV25...
# 1   10-Jan-2024  https://nsearchives.nseindia.com/365d/SGBOCT27...
# 2   10-Jan-2024  https://nsearchives.nseindia.com/365d/SGBOCT25...
# 3   09-Jan-2024  https://nsearchives.nseindia.com/365d/SGBDC27V...
# 4   10-Jan-2024  https://nsearchives.nseindia.com/365d/SGBFEB29...
# ..          ...                                                ...
# 56  10-Jan-2024  https://nsearchives.nseindia.com/365d/SGBJUN29...
# 57  09-Jan-2024  https://nsearchives.nseindia.com/365d/SGBOCT26...
# 58  10-Jan-2024  https://nsearchives.nseindia.com/365d/SGBSEP31...
# 59  10-Jan-2024  https://nsearchives.nseindia.com/365d/SGBJAN30...
# 60  10-Jan-2024  https://nsearchives.nseindia.com/365d/SGBDE30I...
#
#      date30dAgo  perChange30d  \
# 0   05-Dec-2024             0
# 1   10-Dec-2024         -0.14
# 2   10-Dec-2024          1.71
# 3   10-Dec-2024          0.19
# 4   10-Dec-2024         -0.29
# ..          ...           ...
# 56  10-Dec-2024          0.32
# 57  09-Dec-2024          0.62
# 58  10-Dec-2024          0.46
# 59  10-Dec-2024          0.33
# 60  10-Dec-2024             2
#
#                                          chart30dPath
# 0   https://nsearchives.nseindia.com/30d/SGBNOV258...
# 1   https://nsearchives.nseindia.com/30d/SGBOCT27V...
# 2   https://nsearchives.nseindia.com/30d/SGBOCT25-...
# 3   https://nsearchives.nseindia.com/30d/SGBDC27VI...
# 4   https://nsearchives.nseindia.com/30d/SGBFEB29X...
# ..                                                ...
# 56  https://nsearchives.nseindia.com/30d/SGBJUN29I...
# 57  https://nsearchives.nseindia.com/30d/SGBOCT26-...
# 58  https://nsearchives.nseindia.com/30d/SGBSEP31I...
# 59  https://nsearchives.nseindia.com/30d/SGBJAN30I...
# 60  https://nsearchives.nseindia.com/30d/SGBDE30II...
#
# [61 rows x 28 columns]

# %% [markdown]
# ## ETF Data

# %%
# Get ETF (Exchange Traded Fund) data
nse.get_all_etf()
# Out:
#          symbol                                           assets    open  \
# 0      AXISCETF                    NIFTY India Consumption Index  118.13
# 1      SBIETFIT                                   Nifty IT Index  464.09
# 2        ITBEES                                     Nifty IT TRI   46.37
# 3         ITETF                         Mirae Asset Nifty IT ETF   44.27
# 4    SBINEQWETF                             Nifty50 Equal Weight   29.84
# ..          ...                                              ...     ...
# 222  PSUBNKIETF              ICICI Prudential Nifty PSU Bank ETF    63.2
# 223       ALPHA                             NIFTY Alpha 50 Index   51.78
# 224     BANKPSU                Nifty PSU Bank Total Return Index   62.53
# 225   NIFMID150  UTI Nifty Midcap 150 Exchange Traded Fund (ETF)  207.01
# 226   VAL30IETF                          Nifty200 Value 30 Index   12.18
#
#        high     low     ltP    chn    per      qty        trdVal  ...  \
# 0    131.26  114.04  120.67   4.29   3.69    14933    1717444.33  ...
# 1       480  453.03  478.65  16.37   3.54     8723    4125019.47  ...
# 2     48.05   46.37   47.88   1.51   3.26  7797177  371457512.28  ...
# 3     45.75    44.1   45.52   1.42   3.22   148321    6739706.24  ...
# 4     30.39   29.03   30.39   0.93   3.16    19918     583995.76  ...
# ..      ...     ...     ...    ...    ...      ...           ...  ...
# 222    63.8   61.26    61.6  -1.59  -2.52   451385    27994897.7  ...
# 223   51.79   50.11    50.3  -1.31  -2.54  2213905   111890758.7  ...
# 224   62.53   60.75   60.86   -1.7  -2.72   909938   55651808.08  ...
# 225  212.87  202.74  202.74  -5.68  -2.73     3651      747724.8  ...
# 226   12.65   11.77   11.77  -0.37  -3.05   237820     2825301.6  ...
#
#     stockIndClosePrice    nearWKH    nearWKL  \
# 0                    0  13.807143 -45.368028
# 1                    0   5.048601 -40.366569
# 2                    0   3.778135 -40.782123
# 3                    0   5.265349 -46.838710
# 4                    0  12.091409  -5.777932
# ..                 ...        ...        ...
# 222                  0  28.950404 -10.000000
# 223                  0  17.419143 -21.762285
# 224                  0  17.878829  -0.181070
# 225                  0  12.912371 -20.635487
# 226                  0  16.760962  -7.685270
#
#                                         chartTodayPath perChange365d  \
# 0    https://nsearchives.nseindia.com/today/AXISCET...         18.24
# 1    https://nsearchives.nseindia.com/today/SBIETFI...         30.29
# 2    https://nsearchives.nseindia.com/today/ITBEESE...         30.28
# 3    https://nsearchives.nseindia.com/today/ITETFEQ...         29.83
# 4    https://nsearchives.nseindia.com/today/SBINEQW...             -
# ..                                                 ...           ...
# 222  https://nsearchives.nseindia.com/today/PSUBNKI...          7.16
# 223  https://nsearchives.nseindia.com/today/ALPHAEQ...             -
# 224  https://nsearchives.nseindia.com/today/BANKPSU...             -
# 225  https://nsearchives.nseindia.com/today/NIFMID1...         14.28
# 226  https://nsearchives.nseindia.com/today/VAL30IE...             -
#
#      date365dAgo                                      chart365dPath  \
# 0    11-Jan-2024  https://nsearchives.nseindia.com/365d/AXISCETF...
# 1    11-Jan-2024  https://nsearchives.nseindia.com/365d/SBIETFIT...
# 2    11-Jan-2024  https://nsearchives.nseindia.com/365d/ITBEES-E...
# 3    11-Jan-2024  https://nsearchives.nseindia.com/365d/ITETF-EQ...
# 4              -                                                  -
# ..           ...                                                ...
# 222  11-Jan-2024  https://nsearchives.nseindia.com/365d/PSUBNKIE...
# 223            -                                                  -
# 224            -                                                  -
# 225  11-Jan-2024  https://nsearchives.nseindia.com/365d/NIFMID15...
# 226            -                                                  -
#
#       date30dAgo perChange30d  \
# 0    11-Dec-2024        -2.74
# 1    11-Dec-2024        -1.55
# 2    11-Dec-2024        -1.66
# 3    11-Dec-2024        -1.92
# 4    11-Dec-2024        -4.18
# ..           ...          ...
# 222  11-Dec-2024       -14.08
# 223  11-Dec-2024       -11.93
# 224  11-Dec-2024        -14.3
# 225  11-Dec-2024        -7.28
# 226  11-Dec-2024       -12.68
#
#                                           chart30dPath
# 0    https://nsearchives.nseindia.com/30d/AXISCETF-...
# 1    https://nsearchives.nseindia.com/30d/SBIETFIT-...
# 2    https://nsearchives.nseindia.com/30d/ITBEES-EQ...
# 3    https://nsearchives.nseindia.com/30d/ITETF-EQ.svg
# 4    https://nsearchives.nseindia.com/30d/SBINEQWET...
# ..                                                 ...
# 222  https://nsearchives.nseindia.com/30d/PSUBNKIET...
# 223  https://nsearchives.nseindia.com/30d/ALPHA-EQ.svg
# 224  https://nsearchives.nseindia.com/30d/BANKPSU-E...
# 225  https://nsearchives.nseindia.com/30d/NIFMID150...
# 226  https://nsearchives.nseindia.com/30d/VAL30IETF...
#
# [227 rows x 28 columns]

# %% [markdown]
# ## ALL Block Deals

# %%
# Get all block deals happened today
nse.get_all_today_block_deals()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # India VIX

# %%
# India (Bharat) VIX (Volatility Index) data
nse.get_india_vix(interval='3Min')
# Out:
# INDIA VIX is No Longer Available on NSE India :(
# Please Use INDIA VIX from MONEYCONTROL
#
#         from Fundamentals import MoneyControl
#         moneycontrol = MoneyControl()
#         moneycontrol.get_india_vix(interval='1') # Only `1d` (for day interval) or `1`  (for minute interval) is supported
# Empty DataFrame
# Columns: []
# Index: []
